# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

loansData = pd.read_csv(('LoanStats3c.csv'), nrows = 1000, skiprows=1)


#Select specific columns into subdata
subdata = pd.DataFrame(columns=['Interest.Rate', 'Annual.Income', 'Home'])
subdata['Interest.Rate'] = loansData.int_rate
subdata['Annual.Income'] = loansData.annual_inc.astype(float)
subdata['Home'] = loansData.home_ownership

#Intercept set to 1.0
subdata['Intercept'] = float(1.0)

#Clean data but replacing na and removing % from interest.rate column
subdata.dropna(inplace=True)
subdata['Interest.Rate'] = map(lambda x: float(x.rstrip('%')), subdata['Interest.Rate'])


#est = smf.ols(formula='int_rate ~ 1 + annual_inc', data=loansData).fit()

#est1 = smf.ols(formula='int_rate ~ 1 + home_ownership + annual_inc', data=loansData).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b9619da3a225> in <module>()
#      24 ## fit a OLS model with intercept on TV and Radio
#      25 X = sm.add_constant(X)
# ---> 26 est = sm.OLS(y, X).fit()
#      27
#      28 est.summary()
#
# /Users/Situ/anaconda/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     689                  **kwargs):
#     690         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 691                                   hasconst=hasconst, **kwargs)
#     692         if "weights" in self._init_keys:
#     693             self._init_keys.remove("weights")
#
# /Users/Situ/anaconda/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
# ...

# %%
subdata.head()
# Out:
#    Interest.Rate  Annual.Income      Home  Intercept
# 0           6.99          58000  MORTGAGE          1
# 1          12.39          78000      RENT          1
# 2          13.66          50000      RENT          1
# 3          17.14         125000  MORTGAGE          1
# 4          13.66          69000      RENT          1

# %%
loansData.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  36805548   39558264      10400        10400            10400   36 months
# 1  38098114   40860827      15000        15000            15000   60 months
# 2  37662224   40425321       7650         7650             7650   36 months
# 3  37612354   40375473      12800        12800            12800   60 months
# 4  37822187   40585251       9600         9600             9600   36 months
#
#   int_rate  installment grade sub_grade     ...      total_rec_late_fee  \
# 0    6.99%       321.08     A        A3     ...                       0
# 1   12.39%       336.64     C        C1     ...                       0
# 2   13.66%       260.20     C        C3     ...                       0
# 3   17.14%       319.08     D        D4     ...                       0
# 4   13.66%       326.53     C        C3     ...                       0
#
#   recoveries collection_recovery_fee  last_pymnt_d last_pymnt_amnt  \
# ...
